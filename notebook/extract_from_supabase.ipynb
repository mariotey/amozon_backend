# %%
import os
import sys
import pandas as pd

sys.path.append(os.path.abspath(".."))

from pipelines import extract_data

# %%
item_df = extract_data.extract_item()

item_df
# Out:
# 2026-05-09 20:01:02,026 [INFO] pipelines.extract_data: Total rows of Item: 89251
#
# Extracting Item: 100%|██████████| 89251/89251 [02:36<00:00, 568.83rows/s]
#       parent_asin                                    item_title  \
# 0      b00yxz4l2q              clockmaker: match 3 puzzle games
# 1      b01ky3o800                           magic voice changer
# 2      b00ng4c8io                            kettlebell workout
# 3      b01do4fota                             soda mobile drink
# 4      b00jxffpf8                          android kitkat guide
# ...           ...                                           ...
# 89246  b01bxh8wi0                           xylo for dash robot
# 89247  b07zzmwfrs                          cute cats wallpapers
# 89248  b006fkky2s                              ptcb exam review
# 89249  b01lxzlemn                                        the cw
# 89250  b079nqjzqm  music mp3 : downloader app download for free
#
# ...

# %%
review_df = extract_data.extract_review()

review_df
