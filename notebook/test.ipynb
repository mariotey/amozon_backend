# %%
import os
import sys

sys.path.append(os.path.join(os.getcwd(), ".."))

from data_loader import load_user, load_user_item, load_item

# %%
user_df = load_user(local_read=True)
user_df
# Out:
#                             user_id  num_reviews  avg_rating_given  \
# 0      ae223tlcv274eett6yjjoj4imcza            3          4.666667
# 1      ae224gvo7ohtyf26u6er6beviuaq            1          5.000000
# 2      ae22567o4nhejdeaxmkgeha24bwa            1          5.000000
# 3      ae225j6y3ofuckvvcrdhxlzkdula            1          5.000000
# 4      ae227rva23epod52v7j7ccryihbq            1          3.000000
# ...                             ...          ...               ...
# 92553  ahzzy3ar4ogdfqgsassvc2rv2s6a            5          5.000000
# 92554  ahzzy6mrmu6pa6yhuwphnrfo47qq            6          4.833333
# 92555  ahzzysil4dhzzl454sqq37wok4gq            1          5.000000
# 92556  ahzzzuba3pttfi67ios2mftjavea            1          5.000000
# 92557  ahzzzy4dflawpbqyfqfwvacngura            4          4.500000
#
#        rating_std  min_rating_given  max_rating_given first_review_date  \
# 0        0.577350                 4                 5        2012-01-09
# 1        0.000000                 5                 5        2016-07-04
# 2        0.000000                 5                 5        2016-03-11
# 3        0.000000                 5                 5        2019-10-18
# 4        0.000000                 3                 3        2012-03-19
# ...           ...               ...               ...               ...
# 92553    0.000000                 5                 5        2015-07-13
# 92554    0.408248                 4                 5        2012-03-20
# 92555    0.000000                 5                 5        2017-11-29
# 92556    0.000000                 5                 5        2014-12-31
# 92557    0.577350                 4                 5        2016-06-03
#
#       last_review_date  total_recency_weight  total_helpful_votes_received  \
# 0           2014-03-30              0.000208                             1
# 1           2016-07-04              0.001218                             3
# 2           2016-03-11              0.000889                             0
# 3           2019-10-18              0.032637                             1
# 4           2012-03-19              0.000017                             1
# ...                ...                   ...                           ...
# 92553       2021-05-23              0.285057                             2
# 92554       2012-12-30              0.000160                             8
# 92555       2017-11-29              0.004962                             1
# 92556       2014-12-31              0.000269                             1
# 92557       2016-08-19              0.004955                            37
#
#        ...  extreme_rating_ratio  positive_rating_ratio  \
# 0      ...              0.666667                    1.0
# 1      ...              1.000000                    1.0
# 2      ...              1.000000                    1.0
# 3      ...              1.000000                    1.0
# 4      ...              0.000000                    0.0
# ...    ...                   ...                    ...
# 92553  ...              1.000000                    1.0
# 92554  ...              0.833333                    1.0
# 92555  ...              1.000000                    1.0
# 92556  ...              1.000000                    1.0
# 92557  ...              0.500000                    1.0
#
#        negative_rating_ratio  avg_price_purchased  free_app_ratio  \
# 0                        0.0               0.0000        1.000000
# 1                        0.0               0.0000        1.000000
# 2                        0.0              29.9500        0.000000
# 3                        0.0               2.9900        0.000000
# 4                        0.0               0.0000        1.000000
# ...                      ...                  ...             ...
# 92553                    0.0               8.9940        0.400000
# 92554                    0.0               1.1650        0.833333
# 92555                    0.0               0.0000        0.000000
# 92556                    0.0               0.0000        1.000000
# 92557                    0.0               0.2475        0.750000
#
#        days_active  reviews_per_day  verified_purchase_ratio  user_segment  \
# 0              812         0.003695                 1.000000    occasional
# 1                1         1.000000                 1.000000      one_time
# 2                1         1.000000                 1.000000      one_time
# 3                1         1.000000                 1.000000      one_time
# 4                1         1.000000                 1.000000      one_time
# ...            ...              ...                      ...           ...
# 92553         2142         0.002334                 1.000000    occasional
# 92554          286         0.020979                 0.833333    occasional
# 92555            1         1.000000                 1.000000      one_time
# 92556            1         1.000000                 1.000000      one_time
# 92557           78         0.051282                 1.000000    occasional
#
#        is_discriminating
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False
# ...                  ...
# 92553              False
# 92554              False
# 92555              False
# 92556              False
# 92557              False
#
# [92558 rows x 25 columns]

# %%
item_df = load_item(local_read=True)
item_df
# Out:
#       parent_asin                                         item_title  \
# 0      b00vrpsgeo                                 accupressure guide
# 1      b076j3sj4g                                     ac market tips
# 2      b01guebbc0                               gem shopping network
# 3      b073rdqzfs                     rovercraft race your space car
# 4      b004669psm               corel paintshop pro x4 [old version]
# ...           ...                                                ...
# 27792  b003gamzfo  norton 360 version 4.0 1 user / 3 pc [download...
# 27793  b00894f95k         quickbooks point of sale pro 2013 new user
# 27794  b088jvtv1k  тurbotax 2019 home and business - only for win...
# 27795  b00094ot7c  scansoft pdf converter professional 3.0 [old v...
# 27796  b0001h5w9g                   hallmark card studio 2005 deluxe
#
#               main_category  \
# 0      appstore for android
# 1      appstore for android
# 2      appstore for android
# 3      appstore for android
# 4                  software
# ...                     ...
# 27792              software
# 27793              software
# 27794              software
# 27795                   NaN
# 27796              software
#
#                                               categories  \
# 0
# 1
# 2
# 3
# 4                               all corel,corel,software
# ...                                                  ...
# 27792                internet security,software,symantec
# 27793                         all intuit,intuit,software
# 27794                           software,tax preparation
# 27795        brands,dragon & scansoft by nuance,software
# 27796  greeting cards,home publishing,lifestyle & hob...
#
#                                              description  \
# 0      Acupressure technique is very ancient and very...
# 1      Application made by fans for fans!Complete and...
# 2                       Watch Gem Shopping Network Live!
# 3      Play The World Famous Car Crafting Runner with...
# 4      Streamlined workspace--easily make powerful ad...
# ...                                                  ...
# 27792
# 27793  Move beyond the cash register. Intuit QuickBoo...
# 27794  TurboTax is tailored to your unique situation—...
# 27795  Product Description,ScanSoft PDF Converter Pro...
# 27796
#
#                                                 features  \
# 0      All the pressing point has been explained with...
# 1      We personally check and use the apps and play ...
# 2      Live Stream!,Call to shop, ask questions, and ...
# 3      14 different planets from the galaxy to race o...
# 4      Photo-editing software with a streamlined, int...
# ...                                                  ...
# 27792  Protects your identity when you buy, bank, and...
# 27793  Buy with confidence from an Intuit Premier Res...
# 27794  TurboTax Home & Business + State is recommende...
# 27795  Powerful document and form creation, conversio...
# 27796  Create unique Hallmark cards for any occasion,...
#
#                                                  details  \
# 0      {"Release Date": "2015", "Date first listed on...
# 1      {"Release Date": "2017", "Date first listed on...
# 2      {"Release Date": "2016", "Date first listed on...
# 3      {"Release Date": "2017", "Date first listed on...
# 4      {"Is Discontinued By Manufacturer": "No", "Lan...
# ...                                                  ...
# 27792  {"Language": "English", "Item model number": "...
# 27793  {"Is Discontinued By Manufacturer": "No", "Pac...
# 27794  {"Package Dimensions": "7.5 x 5.5 x 0.7 inches...
# 27795  {"Language": "English", "Package Dimensions": ...
# 27796                                                 {}
#
#                                              item_images  \
# 0      {"hi_res": [null, null, null, null], "large": ...
# 1      {"hi_res": [null, null, null, null, null, null...
# 2      {"hi_res": [null, null, null, null, null, null...
# 3      {"hi_res": [null, null, null, null, null, null...
# 4      {"hi_res": [null], "large": ["https://m.media-...
# ...                                                  ...
# 27792  {"hi_res": ["https://m.media-amazon.com/images...
# 27793  {"hi_res": ["https://m.media-amazon.com/images...
# 27794  {"hi_res": ["https://m.media-amazon.com/images...
# 27795  {"hi_res": [null], "large": ["https://m.media-...
# 27796  {"hi_res": [null], "large": ["https://m.media-...
#
#                                              item_videos  item_rating  ...  \
# 0                {"title": [], "url": [], "user_id": []}          NaN  ...
# 1                {"title": [], "url": [], "user_id": []}          NaN  ...
# 2                {"title": [], "url": [], "user_id": []}        816.0  ...
# 3      {"title": [], "url": ["https://images-na.ssl-i...        154.0  ...
# 4                {"title": [], "url": [], "user_id": []}        139.0  ...
# ...                                                  ...          ...  ...
# 27792            {"title": [], "url": [], "user_id": []}        136.0  ...
# 27793            {"title": [], "url": [], "user_id": []}          9.0  ...
# 27794            {"title": [], "url": [], "user_id": []}        146.0  ...
# 27795            {"title": [], "url": [], "user_id": []}         34.0  ...
# 27796            {"title": [], "url": [], "user_id": []}         44.0  ...
#
#       total_helpful_votes  avg_helpful_votes  num_verified_reviews  \
# 0                       2           1.000000                     2
# 1                       6           6.000000                     1
# 2                       6           0.666667                     9
# 3                       0           0.000000                     1
# 4                       6           1.500000                     1
# ...                   ...                ...                   ...
# 27792                   0           0.000000                     1
# 27793                   3           3.000000                     1
# 27794                   0           0.000000                     0
# 27795                   6           6.000000                     0
# 27796                   0           0.000000                     1
#
#        positive_review_ratio  negative_review_ratio  days_on_platform  \
# 0                   1.000000               0.000000                34
# 1                   0.000000               1.000000                 1
# 2                   0.666667               0.222222              1048
# 3                   1.000000               0.000000                 1
# 4                   1.000000               0.000000               344
# ...                      ...                    ...               ...
# 27792               1.000000               0.000000                 1
# 27793               0.000000               1.000000                 1
# 27794               0.000000               1.000000                 1
# 27795               0.000000               1.000000                 1
# 27796               1.000000               0.000000                 1
#
#       reviews_per_day  verified_review_ratio  popularity_segment  \
# 0            0.058824                   1.00        low_coverage
# 1            1.000000                   1.00          cold_start
# 2            0.008588                   1.00        low_coverage
# 3            1.000000                   1.00          cold_start
# 4            0.011628                   0.25        low_coverage
# ...               ...                    ...                 ...
# 27792        1.000000                   1.00          cold_start
# 27793        1.000000                   1.00          cold_start
# 27794        1.000000                   0.00          cold_start
# 27795        1.000000                   0.00          cold_start
# 27796        1.000000                   1.00          cold_start
#
#        quality_score
# 0           0.342372
# 1           0.000000
# 2           0.354197
# 3           0.206543
# 4           0.510100
# ...              ...
# 27792       0.206543
# 27793       0.000000
# 27794       0.000000
# 27795       0.000000
# 27796       0.206543
#
# [27797 rows x 36 columns]

# %%
review_df = load_user_item(local_read=True)
review_df
# Out:
#        review_id        asin parent_asin                       user_id  \
# 0          60496  b017250d16  b017250d16  aexrdwc3ij4ogcfwxumf3kqsndbq
# 1          60497  b01msbcrdy  b01msbcrdy  aestczq3vayrtihcyt5arnpop2ya
# 2          60498  b06xhzxm27  b06xhzxm27  aestczq3vayrtihcyt5arnpop2ya
# 3          60499  b01n3uv5uv  b01n3uv5uv  aestczq3vayrtihcyt5arnpop2ya
# 4          60500  b009p8emck  b009p8emck  afb7qmkbboagqffksudjs4cxgtzq
# ...          ...         ...         ...                           ...
# 244004    142434  b072c5b374  b072c5b374  ah5umajbbtlqt3rils6lrjefge5q
# 244005    142435  b006p2y2qk  b006p2y2qk  ahqf4l2z7ebtq6i6winjcvuimhua
# 244006    142436  b00p03d4d2  b00p03d4d2  afndg3owkrlv4v2qvzcjk5ecxiaa
# 244007    142437  b00wkj07ac  b00wkj07ac  ahwq3lp5tztgmtmmdhjjwqxdgflq
# 244008    142438  b0000azjvg  b0000azjvg  ah2h5tkjbkp4l6jzpef3ots6ewda
#
#        review_date                            review_title  \
# 0       2016-03-14  missing fast forward on cbs all access
# 1       2020-06-18                              needs work
# 2       2020-01-09   very poor performance on firestick 4k
# 3       2019-08-15                     good but needs work
# 4       2018-01-22           kids shows on demand, freeeee
# ...            ...                                     ...
# 244004  2020-01-18                       no cable provider
# 244005  2014-03-25                               solitaire
# 244006  2016-05-14                  echo dot--great system
# 244007  2015-07-19                     upgrade worked well
# 244008  2003-12-13                     great research tool
#
#                                               review_text review_images  \
# 0       cbs all access was east to set up on my amazon...            []
# 1       using a roku ultra or a 4k firestick the playb...            []
# 2       substantial pixelation, choppiness loaded with...            []
# 3       the cnbc live app plays perfectly on my roku d...            []
# 4       great way to waste the time and have something...            []
# ...                                                   ...           ...
# 244004  cant watch this network unless you give login ...            []
# 244005  fun rainy day game with the grandchildren. bet...            []
# 244006  echo dot...fabulous! it's everything the websi...            []
# 244007  great program updated my fmp12 advanced quite ...            []
# 244008  i've been using onenote since the beta, and ha...            []
#
#         verified_purchase  helpful_vote  ...  review_title_length  \
# 0                    True            28  ...                   38
# 1                    True             1  ...                   10
# 2                    True             0  ...                   37
# 3                    True             4  ...                   19
# 4                    True             6  ...                   29
# ...                   ...           ...  ...                  ...
# 244004               True             0  ...                   17
# 244005               True             0  ...                    9
# 244006               True             0  ...                   22
# 244007               True             0  ...                   19
# 244008              False            20  ...                   19
#
#         review_word_count  is_extreme_rating  is_positive  is_negative  \
# 0                     106              False        False        False
# 1                      29              False        False         True
# 2                      30               True        False         True
# 3                      69              False        False        False
# 4                      35               True         True        False
# ...                   ...                ...          ...          ...
# 244004                 21               True        False         True
# 244005                 22              False         True        False
# 244006                 12               True         True        False
# 244007                  8              False        False        False
# 244008                289               True         True        False
#
#         num_review_img  days_since_review  review_year  review_month  \
# 0                    0               2563         2016             3
# 1                    0               1006         2020             6
# 2                    0               1167         2020             1
# 3                    0               1314         2019             8
# 4                    0               1884         2018             1
# ...                ...                ...          ...           ...
# 244004               0               1158         2020             1
# 244005               0               3283         2014             3
# 244006               0               2502         2016             5
# 244007               0               2802         2015             7
# 244008               0               7038         2003            12
#
#         recency_weight
# 0         8.964110e-04
# 1         6.365497e-02
# 2         4.096358e-02
# 3         2.739113e-02
# 4         5.752557e-03
# ...                ...
# 244004    4.198549e-02
# 244005    1.248542e-04
# 244006    1.059347e-03
# 244007    4.659380e-04
# 244008    4.281365e-09
#
# [244009 rows x 22 columns]
