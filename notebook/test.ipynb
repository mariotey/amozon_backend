# %%
import os
import sys

sys.path.append(os.path.join(os.getcwd(), ".."))

from models_loader import ModelsLoader
from data_loader import DataLoader
# Out:
# Model Artefacts successfully loaded!
#
#
# Tabular Data successfully loaded!

# %%
artefact_obj = ModelsLoader()

artefact_obj
# Out:
# Reading models for `collaborative_filtering` from local drive...
#
# Artefacts successfully loaded for `collaborative_filtering`!
#
# Reading data from local drive...
# Reading data from local drive...
# Reading data from local drive...
# Reading models for `content_based_filtering` from local drive...
#
# Artefacts successfully loaded for `content_based_filtering`!

# %%
data_obj = DataLoader()

data_obj.user_item_df
# Out:
# Reading data from local drive...
# Reading data from local drive...
# Reading data from local drive...
#        review_id        asin parent_asin                       user_id  \
# 0         142439  b00kdsgipk  b00kdsgipk  aeey3xdexjodxs7upuscka4lb6ba
# 1         142440  b01l7sj9be  b01l7sj9be  agpflkxgdth4g5ldr2w4itejhvra
# 2         142441  b004k4ry9m  b004k4ry9m  agpflkxgdth4g5ldr2w4itejhvra
# 3         142442  b01n9mbfme  b01n9mbfme  ahfwvukhrrjzruiafxbqkk2ugp5a
# 4         142443  b017bqlu4a  b017bqlu4a  ahfwvukhrrjzruiafxbqkk2ugp5a
# ...          ...         ...         ...                           ...
# 244004    221793  b005hio8da  b005hio8da  ags7tz22rjrzbunozk2xnwjzst7q
# 244005    221794  b0071q75ao  b0071q75ao  ags7tz22rjrzbunozk2xnwjzst7q
# 244006    221795  b004j1ayw0  b004j1ayw0  ags7tz22rjrzbunozk2xnwjzst7q
# 244007    221796  b004lzfwjo  b004lzfwjo  ags7tz22rjrzbunozk2xnwjzst7q
# 244008    221839  b00s4jopi2  b00s4jopi2  agd2lwhtgulxmxdrrw6caj7zosgq
#
#        review_date                      review_title  \
# 0       2021-01-22                     good free tv!
# 1       2017-02-10        i find it very easy to use
# 2       2014-02-17                 can't put it down
# 3       2017-10-05      i truly don't like this game
# 4       2017-06-29    very fun and challenging game!
# ...            ...                               ...
# 244004  2012-03-25                    no real value.
# 244005  2012-02-21        doesn't do what it claims.
# 244006  2012-01-26                           well...
# 244007  2011-10-29  it's a game, free, and it works.
# 244008  2016-06-25                         newcomer!
#
#                                               review_text review_images  \
# 0       for shows like the rifleman, it would be nice ...            []
# 1       i've been using turbotax for years, i find it ...            []
# 2       love to play this game, one of the few i play....            []
# 3       i truly don't like this game, but why a 4 star...            []
# 4       i am addicted to this game...have had it for l...            []
# ...                                                   ...           ...
# 244004  this app tries to be a decent app. but it fail...            []
# 244005  if the actual description didn't say that it d...            []
# 244006  the game is what it is. it works. the problem ...            []
# 244007  other than that it's a snooze-fest. you have m...            []
# 244008  lots of fun so far. will recommend to my friends.            []
#
#         verified_purchase  helpful_vote  ...  review_title_length  \
# 0                    True             1  ...                   13
# 1                   False             0  ...                   26
# 2                    True             0  ...                   17
# 3                    True             0  ...                   28
# 4                    True             1  ...                   30
# ...                   ...           ...  ...                  ...
# 244004              False             2  ...                   14
# 244005              False             0  ...                   26
# 244006               True             6  ...                    7
# 244007              False             0  ...                   32
# 244008               True             0  ...                    9
#
#         review_word_count  is_extreme_rating  is_positive  is_negative  \
# 0                      40              False         True        False
# 1                      61               True         True        False
# 2                      35               True         True        False
# 3                      57              False         True        False
# 4                     132              False         True        False
# ...                   ...                ...          ...          ...
# 244004                 49               True        False         True
# 244005                 41               True        False         True
# 244006                 65              False        False        False
# 244007                 52              False        False        False
# 244008                 10               True         True        False
#
#         num_review_img  days_since_review  review_year  review_month  \
# 0                    0                788         2021             1
# 1                    0               2230         2017             2
# 2                    0               3319         2014             2
# 3                    0               1993         2017            10
# 4                    0               2091         2017             6
# ...                ...                ...          ...           ...
# 244004               0               4013         2012             3
# 244005               0               4046         2012             2
# 244006               0               4072         2012             1
# 244007               0               4161         2011            10
# 244008               0               2460         2016             6
#
#         recency_weight
# 0             0.115622
# 1             0.002231
# 2             0.000113
# 3             0.004268
# 4             0.003264
# ...                ...
# 244004        0.000017
# 244005        0.000015
# 244006        0.000014
# 244007        0.000011
# 244008        0.001188
#
# [244009 rows x 22 columns]
